# %%
a = [1 , 2 , 3]

# %%
a = [1 , 2 ,
    3 , 4 ,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a = [1 , # item1 
    2 , # item 2
     3]
a
# Out:
# [1, 2, 3]

# %%
a = (1,
     2 , # commnet
     3)   
a
# Out:
# (1, 2, 3)

# %%
a = {"key1": 1 # value for key 1
    , "key": 2 #value fot key 2
    }
a
# Out:
# {'key1': 1, 'key': 2}

# %%
def my_func(a , # this use to indicate ...
            b , # commnet
            c):
    print(a , b , c)

my_func(10 , # commnet
        20 , # comment 2
        30)  # comment 3
# Out:
# 10 20 30
