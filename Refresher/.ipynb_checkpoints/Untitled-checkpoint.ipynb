# %%
a = 10 
b = 20
c = 30

# %%
if a > 5 \
and b > 10 \
and c > 20:
    print("Gaso")
# Out:
# Gaso

# %%
a = ''' This is a String 
 by Behnam '''
a
# Out:
# ' This is a String \n by Behnam '

# %%
print(a)
# Out:
#  This is a String
# by Behnam

# %%
b = """ Behnam Safari
    is a handsome 
          person and very smart guy"""
b
# Out:
# ' Behnam Safari\n    is a handsome \n          person and very smart guy'

# %%
print (b)
# Out:
#  Behnam Safari
#     is a handsome
#           person and very smart guy

# %%
def my_func():
    a = ''' a multi-line string 
that is indented in the second line'''
    return a

# %%
print(my_func())
# Out:
#  a multi-line string
# that is indented in the second line
