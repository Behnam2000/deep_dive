# %% [markdown]
# # Functions

# %%
s = [1 , 2 , 3]

len(s)
# Out:
# 3

# %% [markdown]
#  ### Import from some module
#  ---

# %%
from math import sqrt
# Out:
# 2.0

# %%
sqrt(4)

# %%
import math

# %%
math.exp(1)

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ### Define our own Functions
# ---

# %%
def func_1():
    print("running func_1")

# %%
func_1()
# Out:
# running func_1

# %%
def func_2(a: int , b: int):
    return a * b

# %%
func_2("a" , 3)
# Out:
# 'aaa'

# %%
func_2([2 , 3] , 3)
# Out:
# [2, 3, 2, 3, 2, 3]

# %%
func_2
# Out:
# <function __main__.func_2(a, b)>

# %%
def func_3():
    return func_4()
    
def func_4():
    return "running func_4"        
func_3()
# Out:
# 'running func_4'

# %%
def func_5():
    return func_6()

func_5()

def func_6():
    print("running func_6")

# %% [markdown]
# #### lambda

# %%
type(func_5)
# Out:
# function

# %%
my_func = func_4

# %%
func_4()
# Out:
# 'running func_4'

# %%
my_func()
# Out:
# 'running func_4'

# %% [markdown]
# lambda does the same thing than def , but it doesn't assign it a name

# %%
lambda x : x ** 2
# Out:
# <function __main__.<lambda>(x)>

# %%
fn1 = lambda x: x ** 2
fn1(2)
# Out:
# 4

# %%
fn1
# Out:
# <function __main__.<lambda>(x)>
